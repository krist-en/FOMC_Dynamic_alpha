# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import yfinance as yf

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Gupta_Text/Portfolio/df.csv') # tone & drift(mom)
fin_q = pd.read_csv('/content/drive/MyDrive/Gupta_Text/Portfolio/quarterly data.csv')# quarterly financial statements
date = pd.read_csv('/content/drive/MyDrive/Gupta_Text/data.csv') # meeting date
date.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         Date  Length (mins)  Negative Emotions Avg  Negative Emotions Min  \
# 0  4/27/2011             58                  0.002                    0.0
# 1  6/22/2011             53                  0.003                    0.0
# 2  11/2/2011             49                  0.003                    0.0
# 3  1/25/2012             67                  0.002                    0.0
# 4  4/25/2012             52                  0.004                    0.0
#
#    Negative Emotions Max  Negative Emotions Std  Anger  Avg  Anger Min  \
# 0                  0.039                  0.005       0.002        0.0
# 1                  0.022                  0.004       0.001        0.0
# 2                  0.010                  0.002       0.002        0.0
# 3                  0.041                  0.007       0.002        0.0
# 4                  0.087                  0.015       0.003        0.0
#
#    Anger Max  Anger Std  ...  Changes in FFR(Between Month)  MPshockSign  \
# 0      0.036      0.005  ...                      -0.336472    -0.010367
# 1      0.007      0.002  ...                       0.000000    -0.007725
# 2      0.006      0.001  ...                       0.133531     0.013475
# 3      0.040      0.007  ...                       0.133531    -0.018613
# 4      0.070      0.013  ...                       0.074108     0.002717
#
#    MPshockPoorman  Negative Tone  Hawkishness  daily S&P return  Chair  \
# 0          -0.005       0.276448     1.666667             0.86%      1
# 1          -0.005       0.176724     0.421053             1.37%      1
# 2           0.010       0.192816     0.315789            -2.79%      1
# 3           0.000       0.124442     0.777778            -0.11%      1
# 4           0.000       0.175591     0.894737             0.38%      1
#
#    EFFR_CHG  BBD MPU Index Based on Access World News  \
# 0      0.00                                 62.227225
# 1      0.00                                 91.964039
# 2      0.00                                 78.179023
# 3     -0.01                                 76.108390
# 4      0.01                                 62.485963
#
#    BBD MPU Index Based on 10 Major Papers
# 0                               97.252195
# 1                              128.347539
# 2                              131.061467
# 3                               99.928718
# 4                               83.979913
#
# [5 rows x 46 columns]

# %%
fin_q['Totaldebt'] = fin_q['dlcq'] + fin_q['dlttq'] # ST + LT debt
fin_q['profitbility'] = fin_q['niq']/fin_q['revtq']
fin_q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40338 entries, 0 to 40337
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gvkey         40338 non-null  int64
#  1   datadate      40338 non-null  object
#  2   fyearq        40338 non-null  int64
#  3   fqtr          40329 non-null  float64
#  4   fyr           40338 non-null  int64
#  5   indfmt        40338 non-null  object
#  6   consol        40338 non-null  object
#  7   popsrc        40338 non-null  object
#  8   datafmt       40338 non-null  object
#  9   tic           40338 non-null  object
#  10  cusip         40338 non-null  object
#  11  conm          40338 non-null  object
#  12  curcdq        40338 non-null  object
#  13  datacqtr      40318 non-null  object
#  14  datafqtr      40317 non-null  object
#  15  atq           39518 non-null  float64
#  16  dlcq          36869 non-null  float64
#  17  dlttq         39305 non-null  float64
#  18  niq           39989 non-null  float64
#  19  revtq         38746 non-null  float64
#  20  costat        40338 non-null  object
#  21  Totaldebt     36809 non-null  float64
#  22  leverage      36809 non-null  float64
#  23  profitbility  38707 non-null  float64
# dtypes: float64(9), int64(3), object(12)
# memory usage: 7.4+ MB

# %%
na_counts_l = fin_q['leverage'].isna().groupby(fin_q['tic']).sum()
print(na_counts_l)
na_counts_p = fin_q['profitbility'].isna().groupby(fin_q['tic']).sum()
print(na_counts_p)
# Out:
# tic
# A        2
# AAL      0
# AAPL     0
# ABBV    10
# ABNB     8
#         ..
# XYL      7
# YUM      0
# ZBH      5
# ZBRA     0
# ZTS      8
# Name: leverage, Length: 497, dtype: int64
# tic
# A       0
# AAL     0
# AAPL    0
# ABBV    3
# ABNB    0
#        ..
# XYL     4
# YUM     0
# ZBH     0
# ZBRA    0
# ZTS     6
# Name: profitbility, Length: 497, dtype: int64

# %%
lev_q = fin_q[['gvkey','datadate','tic','atq','Totaldebt','leverage']]
lev_q = lev_q.merge(df, left_on='tic', right_on='tiker', how='inner')
lev_q['tone_lev'] = lev_q['negative tone']*lev_q['leverage']
lev_q.head()
# Out:
#    gvkey    datadate  tic      atq  Totaldebt  leverage tiker     drift  \
# 0   1045  2000-03-31  AAL  24314.0     6016.0  0.247429   AAL  0.591604
# 1   1045  2000-06-30  AAL  25473.0     6137.0  0.240922   AAL  0.591604
# 2   1045  2000-09-30  AAL  25899.0     5966.0  0.230356   AAL  0.591604
# 3   1045  2000-12-31  AAL  26213.0     6270.0  0.239194   AAL  0.591604
# 4   1045  2001-03-31  AAL  26534.0     6573.0  0.247720   AAL  0.591604
#
#    negative tone  tone_lev
# 0      -0.108493 -0.026844
# 1      -0.108493 -0.026138
# 2      -0.108493 -0.024992
# 3      -0.108493 -0.025951
# 4      -0.108493 -0.026876

# %%
pro_q = fin_q[['gvkey','datadate','tic','atq','profitbility','niq','revtq']]
pro_q = pro_q.merge(df, left_on='tic', right_on='tiker', how='inner')
pro_q['tone_p'] = pro_q['negative tone']*pro_q['profitbility']
pro_q.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#    gvkey    datadate  tic      atq  profitbility    niq   revtq tiker  \
# 0   1045  2000-03-31  AAL  24314.0      0.028840  132.0  4577.0   AAL
# 1   1045  2000-06-30  AAL  25473.0      0.064059  321.0  5011.0   AAL
# 2   1045  2000-09-30  AAL  25899.0      0.059551  313.0  5256.0   AAL
# 3   1045  2000-12-31  AAL  26213.0      0.009673   47.0  4859.0   AAL
# 4   1045  2001-03-31  AAL  26534.0     -0.009034  -43.0  4760.0   AAL
#
#       drift  negative tone    tone_p
# 0  0.591604      -0.108493 -0.003129
# 1  0.591604      -0.108493 -0.006950
# 2  0.591604      -0.108493 -0.006461
# 3  0.591604      -0.108493 -0.001049
# 4  0.591604      -0.108493  0.000980

# %%
# merge new tone_profitibility date with meeting in covering quarters
date['Date'] = pd.to_datetime(date['Date'], format='%m/%d/%Y')
date['quarter'] = date['Date'].dt.to_period('Q')
date = date[['Date','quarter']]
pro_q['datadate'] = pd.to_datetime(pro_q['datadate'], format='%Y-%m-%d')  # Adjust format if needed
pro_q['datafqtr'] = pro_q['datadate'].dt.to_period('Q')
pro_q = pro_q.merge(date, left_on='datafqtr', right_on='quarter', how='inner')
pro_q.rename(columns={'datadate': 'report_date','Date':'meeting_date'}, inplace=True)
pro_q.drop(columns=['tic','quarter'], inplace=True)
pro_q.head()
# Out:
#    gvkey report_date        atq  profitbility       niq     revtq tiker  \
# 0   1045  2011-06-30  25787.000     -0.046778  -286.000  6114.000   AAL
# 1   1045  2011-06-30  25787.000     -0.046778  -286.000  6114.000   AAL
# 2   1075  2011-06-30  12474.080      0.108383    86.685   799.799   PNW
# 3   1075  2011-06-30  12474.080      0.108383    86.685   799.799   PNW
# 4   1078  2011-06-30  62004.241      0.202030  1942.782  9616.291   ABT
#
#       drift  negative tone    tone_p datafqtr meeting_date
# 0  0.591604      -0.108493  0.005075   2011Q2   2011-04-27
# 1  0.591604      -0.108493  0.005075   2011Q2   2011-06-22
# 2  0.818746      -0.381895 -0.041391   2011Q2   2011-04-27
# 3  0.818746      -0.381895 -0.041391   2011Q2   2011-06-22
# 4  0.374046      -0.071820 -0.014510   2011Q2   2011-04-27

# %%
tic = pro_q['tiker'].tolist()
start_date = '2011-02-01'
end_date = '2020-09-30'
price = yf.download(tic, start=start_date, end=end_date)['Adj Close']
# Out:
# [*********************100%%**********************]  485 of 485 completed

# %%
# # use 1/price as position for each stock on each date, deploy when stocks are in portfolio
# weight = 1/price
# weight.head()

# %%
ret = (price/price.shift(1)-1)
# Reset index to have 'date', 'tiker', and 'return' columns
ret = ret.reset_index()
ret_melt = ret.melt(id_vars=['Date'], var_name='tiker', value_name='return')
# weight_melt = weight.reset_index()
# weight_melt = weight_melt.melt(id_vars=['Date'], var_name='tiker', value_name='weight')
# ret_weight  = ret_melt.merge(weight_melt, on=['Date','tiker'], how='inner')
ret_melt.head()
# Out:
#         Date tiker    return
# 0 2011-02-01     A       NaN
# 1 2011-02-02     A -0.019501
# 2 2011-02-03     A -0.005821
# 3 2011-02-04     A  0.048793
# 4 2011-02-07     A  0.033728

# %%
pro_q_ret = pro_q.merge(ret_melt, left_on=['meeting_date','tiker'], right_on=['Date','tiker'], how='inner')
pro_q_ret.drop(columns=['Date'], inplace=True)
pro_q_ret.head()
# Out:
#    gvkey report_date        atq  profitbility       niq     revtq tiker  \
# 0   1045  2011-06-30  25787.000     -0.046778  -286.000  6114.000   AAL
# 1   1045  2011-06-30  25787.000     -0.046778  -286.000  6114.000   AAL
# 2   1075  2011-06-30  12474.080      0.108383    86.685   799.799   PNW
# 3   1075  2011-06-30  12474.080      0.108383    86.685   799.799   PNW
# 4   1078  2011-06-30  62004.241      0.202030  1942.782  9616.291   ABT
#
#       drift  negative tone    tone_p datafqtr meeting_date    return
# 0  0.591604      -0.108493  0.005075   2011Q2   2011-04-27 -0.005682
# 1  0.591604      -0.108493  0.005075   2011Q2   2011-06-22 -0.019653
# 2  0.818746      -0.381895 -0.041391   2011Q2   2011-04-27  0.003952
# 3  0.818746      -0.381895 -0.041391   2011Q2   2011-06-22 -0.005193
# 4  0.374046      -0.071820 -0.014510   2011Q2   2011-04-27  0.007919

# %%
ticker_counts = pro_q_ret.groupby('tiker').size().reset_index(name='count')
ticker_counts
# Out:
#     tiker  count
# 0       A     46
# 1     AAL     46
# 2    AAPL     46
# 3    ABBV     46
# 4     ABT     46
# ..    ...    ...
# 480   XYL     46
# 481   YUM     46
# 482   ZBH     46
# 483  ZBRA     46
# 484   ZTS     46
#
# [485 rows x 2 columns]

# %%
def get_long_short(data,feature):
    df_sorted = data.sort_values(by=feature)
    num_samples = len(df_sorted)
    top_tail_count = int(num_samples * 0.40)
    long_10_percent_t = df_sorted.tail(top_tail_count)
    short_10_percent_t = df_sorted.head(top_tail_count)
    # Add a column indicating whether it's long or short
    long_10_percent_t['position'] = 1
    short_10_percent_t['position'] = -1
    # Combine long and short positions into one DataFrame
    combined_df = pd.concat([long_10_percent_t, short_10_percent_t])
    return combined_df

# Dictionary to store results
results_dict = {}

# Populate the dictionary with meeting_date as key and combined DataFrame as value
for date, group in pro_q_ret.groupby('meeting_date'):
  formatted_date = date.strftime('%Y-%m-%d')  # Format the date to remove time
  results_dict[formatted_date] = get_long_short(group,'tone_p')
# Out:
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1
# <ipython-input-70-eb970dfc49bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_10_percent_t['position'] = 1
# <ipython-input-70-eb970dfc49bb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_10_percent_t['position'] = -1

# %%
results_list = []

for date, result in results_dict.items():
    print(f"Date: {date}")
    long_positions = result[result['position'] == 1]
    short_positions = result[result['position'] == -1]
    ret_sum_long = (result['position'] * result['return']).sum()/ len(long_positions)
    ret_sum_short = (result['position'] * result['return']).sum()/ len(short_positions)
    ret_sum = ret_sum_long + ret_sum_short
    print(f"Total return equals position * return, daily: {ret_sum}")
    print("\n")
    print(result[['meeting_date','tiker','position','negative tone','tone_p','return']])
    print("\n")
    results_list.append({'Date': date, 'Total Return': ret_sum})
# Out:
# Date: 2011-04-27
# Total return equals position * return, daily: 0.011420759311478488
#
#
#     meeting_date tiker  position  negative tone    tone_p    return
# 34    2011-04-27  AMAT         1      -0.052228 -0.008921  0.019859
# 94    2011-04-27   CAG         1      -0.110663 -0.008788  0.012900
# 414   2011-04-27   UDR         1      -0.089803 -0.008648  0.009524
# 380   2011-04-27     T         1      -0.075382 -0.008595  0.015514
# 846   2011-04-27  LDOS         1      -0.175227 -0.008540  0.007463
# ..           ...   ...       ...            ...       ...       ...
# 126   2011-04-27    DD        -1      -0.296170 -0.019694 -0.001251
# 330   2011-04-27    PH        -1      -0.228694 -0.019597 -0.050868
# 136   2011-04-27   ECL        -1      -0.261715 -0.019396  0.019717
# 456   2011-04-27    IT        -1      -0.219727 -0.019369  0.013431
# 190   2011-04-27  WELL        -1      -0.081166 -0.019346  0.007573
#
# [370 rows x 6 columns]
#
#
# Date: 2011-06-22
# Total return equals position * return, daily: -0.004516923216800763
#
#
#     meeting_date tiker  position  negative tone    tone_p    return
# 35    2011-06-22  AMAT         1      -0.052228 -0.008921 -0.007886
# 95    2011-06-22   CAG         1      -0.110663 -0.008788  0.019655
# 415   2011-06-22   UDR         1      -0.089803 -0.008648 -0.007990
# 381   2011-06-22     T         1      -0.075382 -0.008595 -0.007393
# 847   2011-06-22  LDOS         1      -0.175227 -0.008540  0.000600
# ..           ...   ...       ...            ...       ...       ...
# 127   2011-06-22    DD        -1      -0.296170 -0.019694 -0.002772
# 331   2011-06-22    PH        -1      -0.228694 -0.019597  0.004760
# 137   2011-06-22   ECL        -1      -0.261715 -0.019396 -0.006561
# 457   2011-06-22    IT        -1      -0.219727 -0.019369 -0.017701
# 191   2011-06-22  WELL        -1      -0.081166 -0.019346 -0.004493
#
# [370 rows x 6 columns]
#
#
# Date: 2011-11-02
# Total return equals position * return, daily: 0.00830714971589639
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 1323   2011-11-02  NFLX         1      -0.172921 -0.006956  0.041204
# 986    2011-11-02    DG         1      -0.143123 -0.006814  0.002302
# 1011   2011-11-02   AJG         1      -0.096645 -0.006767  0.018729
# 1312   2011-11-02   GPN         1      -0.058573 -0.006755  0.027159
# 1085   2011-11-02   OKE         1      -0.234100 -0.006613  0.025624
# ...           ...   ...       ...            ...       ...       ...
# 1091   2011-11-02    PH        -1      -0.228694 -0.017723  0.030700
# 1295   2011-11-02  AKAM        -1      -0.095039 -0.017638  0.043919
# 1194   2011-11-02  IDXX        -1      -0.141388 -0.017494  0.022280
# 1078   2011-11-02   XEL        -1      -0.314372 -0.017198  0.024594
# 1000   2011-11-02   XOM        -1      -0.194854 -0.017051  0.018831
#
# [370 rows x 6 columns]
#
#
# Date: 2012-01-25
# Total return equals position * return, daily: -0.010462617317076161
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 1516   2012-01-25   LMT         1      -0.126332 -0.007473 -0.006202
# 1488   2012-01-25   HPQ         1      -0.151928 -0.007425 -0.007013
# 1503   2012-01-25     J         1      -0.238814 -0.007416  0.017132
# 1704   2012-01-25  TSCO         1      -0.186568 -0.007373  0.001239
# 1791   2012-01-25   PFG         1      -0.072442 -0.007331 -0.002923
# ...           ...   ...       ...            ...       ...       ...
# 1768   2012-01-25   TDY        -1      -0.252916 -0.018278  0.015575
# 1636   2012-01-25  CINF        -1      -0.209196 -0.018246  0.009251
# 1534   2012-01-25  VTRS        -1      -0.221179 -0.018028  0.017754
# 1663   2012-01-25  IDXX        -1      -0.141388 -0.017852  0.004737
# 1681   2012-01-25  MTCH        -1      -0.330674 -0.017797 -0.010329
#
# [374 rows x 6 columns]
#
#
# Date: 2012-04-25
# Total return equals position * return, daily: -0.007349069661914564
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 2403   2012-04-25  REGN         1      -0.032700 -0.008244  0.037294
# 2579   2012-04-25   VTR         1      -0.067788 -0.008209  0.023255
# 2233   2012-04-25   EIX         1      -0.225052 -0.008144  0.013225
# 2349   2012-04-25   WRB         1      -0.100639 -0.007937  0.004012
# 2055   2012-04-25   HPQ         1      -0.151928 -0.007885  0.015957
# ...           ...   ...       ...            ...       ...       ...
# 2279   2012-04-25   RTX        -1      -0.194793 -0.018736 -0.000501
# 2511   2012-04-25   DRI        -1      -0.255167 -0.018679  0.008137
# 2687   2012-04-25   DPZ        -1      -0.245893 -0.018367  0.046552
# 2713   2012-04-25   WBD        -1      -0.070229 -0.018274  0.013983
# 2147   2012-04-25  VTRS        -1      -0.221179 -0.018156  0.011851
#
# [374 rows x 6 columns]
#
#
# Date: 2012-06-20
# Total return equals position * return, daily: 0.01171979292366139
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 2404   2012-06-20  REGN         1      -0.032700 -0.008244 -0.006638
# 2580   2012-06-20   VTR         1      -0.067788 -0.008209  0.001635
# 2234   2012-06-20   EIX         1      -0.225052 -0.008144 -0.009586
# 2350   2012-06-20   WRB         1      -0.100639 -0.007937 -0.002388
# 2056   2012-06-20   HPQ         1      -0.151928 -0.007885  0.016819
# ...           ...   ...       ...            ...       ...       ...
# 2280   2012-06-20   RTX        -1      -0.194793 -0.018736 -0.006413
# 2512   2012-06-20   DRI        -1      -0.255167 -0.018679 -0.000777
# 2688   2012-06-20   DPZ        -1      -0.245893 -0.018367 -0.021213
# 2714   2012-06-20   WBD        -1      -0.070229 -0.018274  0.013117
# 2148   2012-06-20  VTRS        -1      -0.221179 -0.018156  0.008904
#
# [374 rows x 6 columns]
#
#
# Date: 2012-09-13
# Total return equals position * return, daily: 0.004318328813750924
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 3042   2012-09-13   WRB         1      -0.100639 -0.007086  0.004764
# 2948   2012-09-13    NI         1      -0.346988 -0.007004  0.010256
# 3207   2012-09-13   AIZ         1      -0.118167 -0.006957  0.012820
# 3065   2012-09-13   HCA         1      -0.151763 -0.006777  0.039095
# 2861   2012-09-13   OMC         1      -0.113101 -0.006770  0.008592
# ...           ...   ...       ...            ...       ...       ...
# 2871   2012-09-13   XOM        -1      -0.194854 -0.018130  0.018760
# 2819   2012-09-13  BALL        -1      -0.357772 -0.018041  0.011852
# 2811   2012-09-13   ADI        -1      -0.069839 -0.017359  0.015649
# 3200   2012-09-13   TDG        -1      -0.091325 -0.017346  0.001049
# 2817   2012-09-13   ADP        -1      -0.148401 -0.017178  0.006796
#
# [374 rows x 6 columns]
#
#
# Date: 2012-12-12
# Total return equals position * return, daily: 0.0014727538029884483
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 3534   2012-12-12   HCA         1      -0.151763 -0.005650 -0.002122
# 3377   2012-12-12    IP         1      -0.168748 -0.005605  0.006733
# 3699   2012-12-12  META         1      -0.136709 -0.005520 -0.014296
# 3301   2012-12-12   CAH         1      -0.456276 -0.005497 -0.002857
# 3622   2012-12-12   PWR         1      -0.092729 -0.005485  0.015202
# ...           ...   ...       ...            ...       ...       ...
# 3550   2012-12-12  SNPS        -1      -0.248167 -0.015889 -0.016104
# 3669   2012-12-12   TDG        -1      -0.091325 -0.015737 -0.020403
# 3449   2012-12-12   AOS        -1      -0.206057 -0.015445 -0.005317
# 3464   2012-12-12   TXN        -1      -0.173362 -0.015363  0.001612
# 3302   2012-12-12   CAT        -1      -0.348578 -0.015114  0.007100
#
# [374 rows x 6 columns]
#
#
# Date: 2013-03-20
# Total return equals position * return, daily: 0.006133919921166449
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 3918   2013-03-20   SHW         1      -0.145803 -0.007817  0.015577
# 4075   2013-03-20  HSIC         1      -0.190324 -0.007591  0.009551
# 3933   2013-03-20   TER         1      -0.322374 -0.007576  0.003049
# 3847   2013-03-20    IP         1      -0.168748 -0.007569  0.014238
# 4056   2013-03-20  TSCO         1      -0.186568 -0.007561  0.017397
# ...           ...   ...       ...            ...       ...       ...
# 3967   2013-03-20    FI        -1      -0.181543 -0.018438  0.007992
# 3878   2013-03-20   MMM        -1      -0.124528 -0.018417  0.004563
# 4026   2013-03-20   LIN        -1      -0.132801 -0.017980  0.001410
# 4120   2013-03-20   TDY        -1      -0.252916 -0.017945  0.008226
# 3745   2013-03-20   AFL        -1      -0.124568 -0.017899  0.018269
#
# [380 rows x 6 columns]
#
#
# Date: 2013-06-19
# Total return equals position * return, daily: 0.004442758823228132
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 4416   2013-06-19   TSN         1      -0.283895 -0.008096 -0.013524
# 4345   2013-06-19   MAS         1      -0.221379 -0.008035 -0.030162
# 4258   2013-06-19     C         1      -0.047349 -0.008034 -0.009598
# 4523   2013-06-19   KDP         1      -0.066754 -0.008026 -0.017499
# 4584   2013-06-19  EBAY         1      -0.047669 -0.007869 -0.006278
# ...           ...   ...       ...            ...       ...       ...
# 4497   2013-06-19   KIM        -1      -0.101981 -0.018092 -0.030983
# 4378   2013-06-19    PH        -1      -0.228694 -0.018089 -0.008815
# 4597   2013-06-19   TDY        -1      -0.252916 -0.018053 -0.014736
# 4240   2013-06-19   BIO        -1      -0.271229 -0.017865 -0.009029
# 4226   2013-06-19   ADI        -1      -0.069839 -0.017424 -0.013287
#
# [380 rows x 6 columns]
#
#
# Date: 2013-09-18
# Total return equals position * return, daily: -0.01423522904166761
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 5023   2013-09-18   WAB         1      -0.071484 -0.008371  0.010678
# 4892   2013-09-18   TSN         1      -0.283895 -0.008331  0.005286
# 4820   2013-09-18   MMC         1      -0.095954 -0.008280  0.024801
# 5096   2013-09-18   PFG         1      -0.072442 -0.008213  0.001595
# 5146   2013-09-18   KKR         1      -0.106995 -0.008155  0.011852
# ...           ...   ...       ...            ...       ...       ...
# 4809   2013-09-18   KMB        -1      -0.187512 -0.019457  0.014010
# 4831   2013-09-18   MMM        -1      -0.124528 -0.019349  0.011340
# 5069   2013-09-18  AKAM        -1      -0.095039 -0.019151  0.015510
# 4965   2013-09-18  IDXX        -1      -0.141388 -0.019095  0.002855
# 4730   2013-09-18   CLX        -1      -0.188466 -0.019085 -0.000355
#
# [380 rows x 6 columns]
#
#
# Date: 2013-12-18
# Total return equals position * return, daily: -0.0009263139748814706
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 5340   2013-12-18   PHM         1      -0.059063 -0.007852  0.021642
# 5409   2013-12-18   WRB         1      -0.100639 -0.007837  0.009964
# 5239   2013-12-18   FMC         1      -0.325983 -0.007813 -0.004517
# 5498   2013-12-18   WAB         1      -0.071484 -0.007767  0.034911
# 5224   2013-12-18    DG         1      -0.143123 -0.007754  0.016940
# ...           ...   ...       ...            ...       ...       ...
# 5456   2013-12-18   STE        -1      -0.266598 -0.018739  0.021730
# 5329   2013-12-18    PH        -1      -0.228694 -0.018649  0.021514
# 5389   2013-12-18  TROW        -1      -0.058956 -0.018242  0.038216
# 5385   2013-12-18   TJX        -1      -0.203957 -0.018189  0.018579
# 5458   2013-12-18  SBUX        -1      -0.142521 -0.018177  0.020897
#
# [380 rows x 6 columns]
#
#
# Date: 2014-03-19
# Total return equals position * return, daily: 0.013797174708571896
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 6115   2014-03-19  ALLE         1      -0.098718 -0.007574  0.000000
# 5853   2014-03-19   WBA         1      -0.199491 -0.007286 -0.005506
# 6049   2014-03-19  NFLX         1      -0.172921 -0.007232 -0.000381
# 5821   2014-03-19   SHW         1      -0.145803 -0.007113 -0.012549
# 6113   2014-03-19  CBRE         1      -0.193822 -0.007048 -0.025097
# ...           ...   ...       ...            ...       ...       ...
# 5899   2014-03-19   PTC        -1      -0.133564 -0.017780 -0.013673
# 5747   2014-03-19  INTC        -1      -0.117247 -0.017728  0.008058
# 5983   2014-03-19  NTAP        -1      -0.148074 -0.017668 -0.009877
# 5856   2014-03-19    WY        -1      -0.157475 -0.017598 -0.014859
# 5963   2014-03-19   AVB        -1      -0.049999 -0.017485 -0.007995
#
# [380 rows x 6 columns]
#
#
# Date: 2014-06-18
# Total return equals position * return, daily: -0.005284512466513523
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 6306   2014-06-18     T         1      -0.075382 -0.008467  0.005140
# 6458   2014-06-18  HSIC         1      -0.190324 -0.008459  0.006422
# 6425   2014-06-18   EQR         1      -0.047654 -0.008330  0.007991
# 6359   2014-06-18    WM         1      -0.140394 -0.008279  0.000904
# 6116   2014-06-18   AAL         1      -0.108493 -0.008245  0.018868
# ...           ...   ...       ...            ...       ...       ...
# 6281   2014-06-18    PH        -1      -0.228694 -0.019528  0.005894
# 6432   2014-06-18   REG        -1      -0.091271 -0.019463  0.007889
# 6258   2014-06-18   MMM        -1      -0.124528 -0.019397  0.004454
# 6399   2014-06-18  PYPL        -1      -0.136534 -0.019348       NaN
# 6236   2014-06-18   KMB        -1      -0.187512 -0.019270  0.008191
#
# [382 rows x 6 columns]
#
#
# Date: 2014-09-17
# Total return equals position * return, daily: 0.009909485739502349
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 7042   2014-09-17  SMCI         1      -0.180326 -0.008486  0.057420
# 6936   2014-09-17  HSIC         1      -0.190324 -0.008326  0.003685
# 6912   2014-09-17   SPG         1      -0.042091 -0.008246  0.001735
# 7028   2014-09-17   ICE         1      -0.040200 -0.008199  0.025507
# 6988   2014-09-17   CRL         1      -0.083358 -0.008152  0.001488
# ...           ...   ...       ...            ...       ...       ...
# 6694   2014-09-17    HD        -1      -0.226652 -0.019514  0.010524
# 6995   2014-09-17  MDLZ        -1      -0.180001 -0.019410 -0.003377
# 6641   2014-09-17   CAG        -1      -0.110663 -0.019300 -0.011121
# 6657   2014-09-17    DD        -1      -0.296170 -0.019265  0.012528
# 6871   2014-09-17  IDXX        -1      -0.141388 -0.019222 -0.014750
#
# [382 rows x 6 columns]
#
#
# Date: 2014-12-17
# Total return equals position * return, daily: 0.0010398930066373216
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 7482   2014-12-17   PFG         1      -0.072442 -0.006943  0.024082
# 7443   2014-12-17  CSGP         1      -0.077703 -0.006931  0.029738
# 7466   2014-12-17   CRL         1      -0.083358 -0.006872  0.017970
# 7384   2014-12-17   KDP         1      -0.066754 -0.006480  0.008871
# 7072   2014-12-17   AAL         1      -0.108493 -0.006375  0.017514
# ...           ...   ...       ...            ...       ...       ...
# 7435   2014-12-17   URI        -1      -0.133521 -0.016562 -0.005215
# 7146   2014-12-17   XOM        -1      -0.194854 -0.016554  0.030205
# 7293   2014-12-17   TJX        -1      -0.203957 -0.016474  0.005230
# 7397   2014-12-17   AVB        -1      -0.049999 -0.015994  0.023651
# 7410   2014-12-17  ACGL        -1      -0.075198 -0.015937  0.009731
#
# [382 rows x 6 columns]
#
#
# Date: 2015-03-18
# Total return equals position * return, daily: -0.011236559199323327
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 7567   2015-03-18  AMAT         1      -0.052228 -0.007705  0.006609
# 7740   2015-03-18     T         1      -0.075382 -0.007551  0.020973
# 7952   2015-03-18  MDLZ         1      -0.180001 -0.007514  0.019208
# 7936   2015-03-18  EXPE         1      -0.232703 -0.007479  0.018520
# 7948   2015-03-18   TPR         1      -0.077610 -0.007358  0.012442
# ...           ...   ...       ...            ...       ...       ...
# 7653   2015-03-18  HUBB        -1      -0.229505 -0.017687  0.004750
# 7827   2015-03-18  IDXX        -1      -0.141388 -0.017224 -0.000198
# 7559   2015-03-18   AXP        -1      -0.093945 -0.017137  0.009869
# 8025   2015-03-18  EPAM        -1      -0.232779 -0.017122 -0.003240
# 7590   2015-03-18  CTAS        -1      -0.197764 -0.016922  0.010556
#
# [384 rows x 6 columns]
#
#
# Date: 2015-06-17
# Total return equals position * return, daily: -0.005496352627972897
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 8049   2015-06-17  ADSK         1      -0.264341 -0.007810  0.002620
# 8047   2015-06-17  AMAT         1      -0.052228 -0.007785 -0.014127
# 8301   2015-06-17   HCA         1      -0.151763 -0.007774  0.013250
# 8501   2015-06-17   HII         1      -0.087317 -0.007748  0.006161
# 8290   2015-06-17   PTC         1      -0.133564 -0.007683  0.001205
# ...           ...   ...       ...            ...       ...       ...
# 8113   2015-06-17     F        -1      -0.303626 -0.017600  0.001334
# 8044   2015-06-17   ADI        -1      -0.069839 -0.017467  0.009005
# 8391   2015-06-17   YUM        -1      -0.230296 -0.017430 -0.005664
# 8130   2015-06-17    HD        -1      -0.226652 -0.017131  0.002177
# 8030   2015-06-17   AAL        -1      -0.108493 -0.017075  0.010132
#
# [382 rows x 6 columns]
#
#
# Date: 2015-09-17
# Total return equals position * return, daily: -0.0058526794005675335
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 8907   2015-09-17   TPR         1      -0.077610 -0.007262 -0.002340
# 8716   2015-09-17   UDR         1      -0.089803 -0.007002  0.008421
# 8816   2015-09-17   CDW         1      -0.162179 -0.006990 -0.012913
# 8712   2015-09-17   TSN         1      -0.283895 -0.006972  0.001375
# 8780   2015-09-17   HCA         1      -0.151763 -0.006914  0.009625
# ...           ...   ...       ...            ...       ...       ...
# 8592   2015-09-17     F        -1      -0.303626 -0.017448 -0.002732
# 8548   2015-09-17   CHD        -1      -0.124303 -0.017366  0.004380
# 8691   2015-09-17   SHW        -1      -0.145803 -0.017321  0.010135
# 8656   2015-09-17   NKE        -1      -0.122487 -0.017163 -0.002682
# 8509   2015-09-17   AAL        -1      -0.108493 -0.017157  0.021598
#
# [382 rows x 6 columns]
#
#
# Date: 2015-12-16
# Total return equals position * return, daily: -0.0037349113365307478
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 9278   2015-12-16   MHK         1      -0.059829 -0.005736  0.031803
# 9151   2015-12-16   PCG         1      -0.170362 -0.005642  0.029032
# 9301   2015-12-16   KDP         1      -0.066754 -0.005543  0.008036
# 9099   2015-12-16    IP         1      -0.168748 -0.005519  0.011006
# 9201   2015-12-16   WMT         1      -0.186741 -0.005255  0.011066
# ...           ...   ...       ...            ...       ...       ...
# 9265   2015-12-16  IDXX        -1      -0.141388 -0.015688  0.008960
# 9027   2015-12-16   CHD        -1      -0.124303 -0.015524  0.012068
# 9153   2015-12-16    PH        -1      -0.228694 -0.015467  0.031664
# 9209   2015-12-16   TJX        -1      -0.203957 -0.015448  0.019873
# 9359   2015-12-16  CTSH        -1      -0.116906 -0.015313  0.031565
#
# [382 rows x 6 columns]
#
#
# Date: 2016-03-16
# Total return equals position * return, daily: -0.0006412721300321915
#
#
#      meeting_date tiker  position  negative tone    tone_p    return
# 9712   2016-03-16   WRB         1      -0.100639 -0.006717 -0.005965
# 9484   2016-03-16  AMAT         1      -0.052228 -0.006618  0.007538
# 9680   2016-03-16   WMT         1      -0.186741 -0.006587 -0.001468
# 9843   2016-03-16  CSGP         1      -0.077703 -0.006505  0.038002
# 9624   2016-03-16   OXY         1      -0.176506 -0.006485  0.015952
# ...           ...   ...       ...            ...       ...       ...
# 9763   2016-03-16  SBUX        -1      -0.142521 -0.016412  0.009987
# 9817   2016-03-16  NTAP        -1      -0.148074 -0.016346  0.017809
# 9884   2016-03-16   TDG        -1      -0.091325 -0.016239  0.004153
# 9842   2016-03-16  CTSH        -1      -0.116906 -0.016108  0.015165
# 9861   2016-03-16    EW        -1      -0.078219 -0.016041 -0.005910
#
# [386 rows x 6 columns]
#
#
# Date: 2016-06-15
# Total return equals position * return, daily: 0.008173763720506768
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 10396   2016-06-15   FIS         1      -0.121519 -0.006379 -0.001763
# 10140   2016-06-15     T         1      -0.075382 -0.006340 -0.002229
# 9997    2016-06-15   CAG         1      -0.110663 -0.006339 -0.002789
# 10186   2016-06-15  PARA         1      -0.043647 -0.006204  0.007194
# 10063   2016-06-15     J         1      -0.238814 -0.006122  0.000196
# ...            ...   ...       ...            ...       ...       ...
# 10282   2016-06-15   ESS        -1      -0.078448 -0.016553  0.019362
# 10017   2016-06-15   ETN        -1      -0.169465 -0.016379  0.003475
# 10038   2016-06-15   GIS        -1      -0.168973 -0.016330 -0.002306
# 10261   2016-06-15   EQR        -1      -0.047654 -0.016057  0.015337
# 10432   2016-06-15  ALLE        -1      -0.098718 -0.016034  0.007837
#
# [386 rows x 6 columns]
#
#
# Date: 2016-09-21
# Total return equals position * return, daily: -0.004355254978389886
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 10784   2016-09-21  NTAP         1      -0.148074 -0.007324  0.020869
# 10647   2016-09-21   WBA         1      -0.199491 -0.007175 -0.000744
# 10710   2016-09-21  REGN         1      -0.032700 -0.007097  0.000689
# 10724   2016-09-21   MHK         1      -0.059829 -0.007038  0.001553
# 10902   2016-09-21  FTNT         1      -0.348420 -0.006922  0.014963
# ...            ...   ...       ...            ...       ...       ...
# 10502   2016-09-21   EMR        -1      -0.151706 -0.016899  0.010738
# 10580   2016-09-21   NKE        -1      -0.122487 -0.016884  0.008566
# 10438   2016-09-21   HON        -1      -0.133188 -0.016845  0.009228
# 10727   2016-09-21   STE        -1      -0.266598 -0.016669  0.011673
# 10694   2016-09-21  PAYC        -1      -0.207748 -0.016652  0.030094
#
# [386 rows x 6 columns]
#
#
# Date: 2016-12-14
# Total return equals position * return, daily: 0.005340348968190422
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 11198   2016-12-14  VRTX         1      -0.088478 -0.006355  0.022585
# 10977   2016-12-14    DG         1      -0.143123 -0.006331 -0.000921
# 11371   2016-12-14  SMCI         1      -0.180326 -0.006220 -0.014035
# 10991   2016-12-14   XOM         1      -0.194854 -0.006180 -0.021603
# 11015   2016-12-14   HPQ         1      -0.151928 -0.005974 -0.013274
# ...            ...   ...       ...            ...       ...       ...
# 11195   2016-12-14  IDXX        -1      -0.141388 -0.016714 -0.008773
# 10941   2016-12-14   BAX        -1      -0.181334 -0.016659  0.000444
# 10927   2016-12-14   AFL        -1      -0.124568 -0.016525 -0.003715
# 11375   2016-12-14   TEL        -1      -0.114617 -0.016460 -0.013687
# 11133   2016-12-14   WDC        -1      -0.340147 -0.016353 -0.010751
#
# [386 rows x 6 columns]
#
#
# Date: 2017-03-15
# Total return equals position * return, daily: -0.009552619314013024
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 11457   2017-03-15    DE         1      -0.250561 -0.009033  0.014468
# 11597   2017-03-15   TFX         1      -0.109217 -0.008992  0.015404
# 11527   2017-03-15   LMT         1      -0.126332 -0.008890  0.005373
# 11447   2017-03-15     C         1      -0.047349 -0.008838 -0.009765
# 11701   2017-03-15   HUM         1      -0.108034 -0.008753  0.004954
# ...            ...   ...       ...            ...       ...       ...
# 11441   2017-03-15  CTAS        -1      -0.197764 -0.018590  0.008527
# 11667   2017-03-15  ANET        -1      -0.074778 -0.018492  0.010079
# 11778   2017-03-15  CTSH        -1      -0.116906 -0.018363  0.001690
# 11781   2017-03-15   CCI        -1      -0.156411 -0.018342  0.013754
# 11869   2017-03-15   KKR        -1      -0.106995 -0.018297  0.009310
#
# [388 rows x 6 columns]
#
#
# Date: 2017-06-14
# Total return equals position * return, daily: 0.00019992981287093913
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 11933   2017-06-14     C         1      -0.047349 -0.008262  0.000464
# 12234   2017-06-14  POOL         1      -0.085446 -0.008206  0.000576
# 12196   2017-06-14   ALL         1      -0.131469 -0.007920  0.009662
# 12101   2017-06-14   WBA         1      -0.199491 -0.007697  0.013203
# 12274   2017-06-14  SBAC         1      -0.350994 -0.007585  0.006513
# ...            ...   ...       ...            ...       ...       ...
# 12151   2017-06-14  CTRA        -1      -0.391291 -0.018293 -0.011554
# 12315   2017-06-14   VST        -1       0.909656 -0.018249  0.026911
# 11975   2017-06-14   GIS        -1      -0.168973 -0.018151  0.009971
# 12237   2017-06-14    EL        -1      -0.228233 -0.018060  0.005381
# 12171   2017-06-14  PYPL        -1      -0.136534 -0.017894 -0.003073
#
# [388 rows x 6 columns]
#
#
# Date: 2017-09-20
# Total return equals position * return, daily: 0.00965993562403797
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 12437   2017-09-20   OMC         1      -0.113101 -0.008015  0.022131
# 12465   2017-09-20   HAL         1      -0.119158 -0.007989  0.018687
# 12824   2017-09-20   PSX         1      -0.215564 -0.007973 -0.000224
# 12633   2017-09-20   PTC         1      -0.133564 -0.007601  0.014250
# 12791   2017-09-20  NFLX         1      -0.172921 -0.007507 -0.000916
# ...            ...   ...       ...            ...       ...       ...
# 12757   2017-09-20  APTV        -1      -0.149673 -0.018780  0.002478
# 12598   2017-09-20  TROW        -1      -0.058956 -0.018605  0.007286
# 12775   2017-09-20  EQIX        -1      -0.264471 -0.018339 -0.008388
# 12461   2017-09-20   GIS        -1      -0.168973 -0.018143 -0.057964
# 12637   2017-09-20  CTRA        -1      -0.391291 -0.017855  0.003052
#
# [388 rows x 6 columns]
#
#
# Date: 2017-12-13
# Total return equals position * return, daily: -0.005641068596841266
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 13335   2017-12-13   HII         1      -0.087317 -0.002800  0.006637
# 13262   2017-12-13   TPR         1      -0.077610 -0.002748  0.018309
# 12996   2017-12-13   CVS         1      -0.040150 -0.002727 -0.016884
# 13062   2017-12-13   UAL         1      -0.044250 -0.002711 -0.005208
# 12944   2017-12-13    GD         1      -0.035001 -0.002689  0.002294
# ...            ...   ...       ...            ...       ...       ...
# 13167   2017-12-13   ALL        -1      -0.131469 -0.016728 -0.002125
# 13002   2017-12-13  VTRS        -1      -0.221179 -0.016683  0.006108
# 13124   2017-12-13  ANET        -1      -0.074778 -0.016595  0.031524
# 12914   2017-12-13    DE        -1      -0.250561 -0.015947  0.005825
# 13056   2017-12-13   TXN        -1      -0.173362 -0.015903  0.004368
#
# [388 rows x 6 columns]
#
#
# Date: 2018-03-21
# Total return equals position * return, daily: 0.004129136640062725
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 13688   2018-03-21  ACGL         1      -0.075198 -0.008996 -0.001396
# 13744   2018-03-21   CRL         1      -0.083358 -0.008882 -0.004890
# 13747   2018-03-21   TPR         1      -0.077610 -0.008234 -0.003949
# 13407   2018-03-21   OMC         1      -0.113101 -0.008230  0.003602
# 13689   2018-03-21    EG         1      -0.066906 -0.008173 -0.002574
# ...            ...   ...       ...            ...       ...       ...
# 13738   2018-03-21   PKG        -1      -0.244339 -0.020248  0.009785
# 13568   2018-03-21  TROW        -1      -0.058956 -0.020142  0.005178
# 13390   2018-03-21   CAG        -1      -0.110663 -0.020130 -0.029388
# 13537   2018-03-21   SYK        -1      -0.146721 -0.020055 -0.010690
# 13653   2018-03-21   CPT        -1      -0.119414 -0.019993 -0.009902
#
# [388 rows x 6 columns]
#
#
# Date: 2018-06-13
# Total return equals position * return, daily: 0.006493363185438448
#
#
#       meeting_date  tiker  position  negative tone    tone_p    return
# 13920   2018-06-13    HAL         1      -0.119158 -0.009906 -0.003970
# 14006   2018-06-13    ROK         1      -0.084470 -0.009876 -0.007658
# 14282   2018-06-13   FSLR         1       0.061708 -0.009674 -0.021541
# 14260   2018-06-13  GOOGL         1      -0.097692 -0.009558 -0.003449
# 14073   2018-06-13    WRB         1      -0.100639 -0.009547 -0.005844
# ...            ...    ...       ...            ...       ...       ...
# 14186   2018-06-13   STLD        -1      -0.188525 -0.022110 -0.012053
# 13868   2018-06-13   CTAS        -1      -0.197764 -0.022053  0.000000
# 13852   2018-06-13    BAX        -1      -0.181334 -0.021982 -0.010219
# 13928   2018-06-13     HD        -1      -0.226652 -0.021841 -0.004967
# 14239   2018-06-13   AXON        -1      -0.254163 -0.021734 -0.006127
#
# [388 rows x 6 columns]
#
#
# Date: 2018-09-26
# Total return equals position * return, daily: 0.005178502262919487
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 14360   2018-09-26   CAG         1      -0.110663 -0.010750 -0.003867
# 14795   2018-09-26  CBRE         1      -0.193822 -0.010701 -0.004715
# 14509   2018-09-26   TFX         1      -0.109217 -0.010126 -0.005766
# 14584   2018-09-26   HCA         1      -0.151763 -0.010059  0.015686
# 14370   2018-09-26   DAL         1      -0.090533 -0.010013  0.007180
# ...            ...   ...       ...            ...       ...       ...
# 14591   2018-09-26  IDXX        -1      -0.141388 -0.024172 -0.005898
# 14569   2018-09-26    EA        -1      -0.119779 -0.023751  0.015828
# 14542   2018-09-26   NVR        -1      -0.225450 -0.023744 -0.014542
# 14752   2018-09-26  DXCM        -1      -0.135829 -0.023733 -0.013606
# 14455   2018-09-26   MMM        -1      -0.124528 -0.023570  0.002042
#
# [388 rows x 6 columns]
#
#
# Date: 2018-12-19
# Total return equals position * return, daily: -0.0030499273816338725
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 14858   2018-12-19    DG         1      -0.143123 -0.007452 -0.012745
# 14893   2018-12-19  WELL         1      -0.081166 -0.007417 -0.003782
# 14999   2018-12-19    GL         1      -0.048389 -0.007409 -0.018330
# 15008   2018-12-19   RTX         1      -0.194793 -0.007406 -0.017101
# 15242   2018-12-19   AMP         1      -0.042500 -0.007141 -0.027030
# ...            ...   ...       ...            ...       ...       ...
# 14822   2018-12-19   BAX        -1      -0.181334 -0.019522 -0.016280
# 15041   2018-12-19    WM        -1      -0.140394 -0.019404 -0.014239
# 14820   2018-12-19  BALL        -1      -0.357772 -0.019273 -0.019453
# 15028   2018-12-19  ADBE        -1      -0.069485 -0.019122 -0.006765
# 14954   2018-12-19   NUE        -1      -0.185371 -0.019043 -0.024559
#
# [388 rows x 6 columns]
#
#
# Date: 2019-01-30
# Total return equals position * return, daily: -0.00044938781686903957
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 15461   2019-01-30    GM         1      -0.153028 -0.009464  0.016117
# 15773   2019-01-30   WRB         1      -0.100639 -0.009445  0.032284
# 15645   2019-01-30   SLB         1      -0.174904 -0.009344  0.022727
# 15285   2019-01-30   PNW         1      -0.381895 -0.009240  0.002977
# 16035   2019-01-30   VTR         1      -0.067788 -0.009052  0.005351
# ...            ...   ...       ...            ...       ...       ...
# 16015   2019-01-30   BXP        -1      -0.157699 -0.021680  0.032202
# 16043   2019-01-30   CCI        -1      -0.156411 -0.021440  0.003651
# 15293   2019-01-30   HON        -1      -0.133188 -0.021229  0.010865
# 15619   2019-01-30   PNR        -1      -0.284712 -0.021202  0.005124
# 16129   2019-01-30   STX        -1      -0.249189 -0.021008  0.022680
#
# [388 rows x 6 columns]
#
#
# Date: 2019-03-20
# Total return equals position * return, daily: -0.012964482337166374
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 15462   2019-03-20    GM         1      -0.153028 -0.009464 -0.033185
# 15774   2019-03-20   WRB         1      -0.100639 -0.009445 -0.003731
# 15646   2019-03-20   SLB         1      -0.174904 -0.009344  0.024046
# 15286   2019-03-20   PNW         1      -0.381895 -0.009240  0.004240
# 16036   2019-03-20   VTR         1      -0.067788 -0.009052  0.009823
# ...            ...   ...       ...            ...       ...       ...
# 16016   2019-03-20   BXP        -1      -0.157699 -0.021680 -0.002647
# 16044   2019-03-20   CCI        -1      -0.156411 -0.021440  0.009553
# 15294   2019-03-20   HON        -1      -0.133188 -0.021229 -0.006042
# 15620   2019-03-20   PNR        -1      -0.284712 -0.021202 -0.010770
# 16130   2019-03-20   STX        -1      -0.249189 -0.021008 -0.022217
#
# [388 rows x 6 columns]
#
#
# Date: 2019-05-01
# Total return equals position * return, daily: 0.009367476357907445
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 16375   2019-05-01     D         1      -0.491267 -0.009256 -0.009375
# 16257   2019-05-01   ABT         1      -0.071820 -0.009055 -0.010306
# 16401   2019-05-01   XOM         1      -0.194854 -0.009037 -0.020055
# 16507   2019-05-01     L         1      -0.127318 -0.008920 -0.019302
# 16951   2019-05-01  HSIC         1      -0.190324 -0.008905 -0.025289
# ...            ...   ...       ...            ...       ...       ...
# 17139   2019-05-01   WBD        -1      -0.070229 -0.023077 -0.000324
# 17027   2019-05-01  SBAC        -1      -0.350994 -0.022438  0.000393
# 16703   2019-05-01  TROW        -1      -0.058956 -0.022290 -0.013302
# 16263   2019-05-01   HON        -1      -0.133188 -0.022205 -0.015493
# 16729   2019-05-01  FICO        -1      -0.108131 -0.022074 -0.031635
#
# [388 rows x 6 columns]
#
#
# Date: 2019-06-19
# Total return equals position * return, daily: -0.007478461834834615
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 16376   2019-06-19     D         1      -0.491267 -0.009256  0.009682
# 16258   2019-06-19   ABT         1      -0.071820 -0.009055  0.010909
# 16402   2019-06-19   XOM         1      -0.194854 -0.009037 -0.005545
# 16508   2019-06-19     L         1      -0.127318 -0.008920  0.004308
# 16952   2019-06-19  HSIC         1      -0.190324 -0.008905  0.000278
# ...            ...   ...       ...            ...       ...       ...
# 17140   2019-06-19   WBD        -1      -0.070229 -0.023077  0.028668
# 17028   2019-06-19  SBAC        -1      -0.350994 -0.022438  0.017121
# 16704   2019-06-19  TROW        -1      -0.058956 -0.022290  0.004097
# 16264   2019-06-19   HON        -1      -0.133188 -0.022205 -0.001935
# 16730   2019-06-19  FICO        -1      -0.108131 -0.022074 -0.001470
#
# [388 rows x 6 columns]
#
#
# Date: 2019-07-31
# Total return equals position * return, daily: 0.0013234497522887536
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 17315   2019-07-31     C         1      -0.047349 -0.008909 -0.007670
# 18047   2019-07-31   WTW         1      -0.232143 -0.008754 -0.011494
# 17343   2019-07-31    DG         1      -0.143123 -0.008744 -0.001341
# 17625   2019-07-31    GL         1      -0.048389 -0.008557 -0.004361
# 17713   2019-07-31   WRB         1      -0.100639 -0.008541 -0.015186
# ...            ...   ...       ...            ...       ...       ...
# 18059   2019-07-31  NFLX        -1      -0.172921 -0.021933 -0.009020
# 17361   2019-07-31   EMR        -1      -0.151706 -0.021881 -0.035815
# 17963   2019-07-31   URI        -1      -0.133521 -0.020983 -0.026164
# 17797   2019-07-31  QCOM        -1      -0.197294 -0.020738 -0.022056
# 18061   2019-07-31   TDG        -1      -0.091325 -0.020552 -0.002220
#
# [388 rows x 6 columns]
#
#
# Date: 2019-09-18
# Total return equals position * return, daily: -0.0006086559226844195
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 17316   2019-09-18     C         1      -0.047349 -0.008909  0.008779
# 18048   2019-09-18   WTW         1      -0.232143 -0.008754  0.000252
# 17344   2019-09-18    DG         1      -0.143123 -0.008744 -0.000765
# 17626   2019-09-18    GL         1      -0.048389 -0.008557  0.006360
# 17714   2019-09-18   WRB         1      -0.100639 -0.008541  0.002055
# ...            ...   ...       ...            ...       ...       ...
# 18060   2019-09-18  NFLX        -1      -0.172921 -0.021933 -0.023577
# 17362   2019-09-18   EMR        -1      -0.151706 -0.021881 -0.000616
# 17964   2019-09-18   URI        -1      -0.133521 -0.020983 -0.017258
# 17798   2019-09-18  QCOM        -1      -0.197294 -0.020738  0.002669
# 18062   2019-09-18   TDG        -1      -0.091325 -0.020552  0.009114
#
# [388 rows x 6 columns]
#
#
# Date: 2019-10-30
# Total return equals position * return, daily: -0.017190954367748035
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 18557   2019-10-30   SHW         1      -0.145803 -0.008810  0.007944
# 18455   2019-10-30   MMC         1      -0.095954 -0.008799  0.014106
# 18307   2019-10-30   DAL         1      -0.090533 -0.008690 -0.001083
# 18281   2019-10-30   AON         1      -0.062755 -0.008135  0.032243
# 18215   2019-10-30   AIG         1      -0.095644 -0.007978  0.009789
# ...            ...   ...       ...            ...       ...       ...
# 19119   2019-10-30  ULTA        -1      -0.274497 -0.021168 -0.007682
# 18749   2019-10-30  IDXX        -1      -0.141388 -0.021133  0.011002
# 18819   2019-10-30    LW        -1      -0.153222 -0.021107  0.009478
# 18237   2019-10-30  BALL        -1      -0.357772 -0.021053  0.016772
# 18231   2019-10-30  ADSK        -1      -0.264341 -0.020923  0.021911
#
# [388 rows x 6 columns]
#
#
# Date: 2019-12-11
# Total return equals position * return, daily: -0.0013116556303269147
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 18558   2019-12-11   SHW         1      -0.145803 -0.008810  0.008128
# 18456   2019-12-11   MMC         1      -0.095954 -0.008799  0.002484
# 18308   2019-12-11   DAL         1      -0.090533 -0.008690 -0.008104
# 18282   2019-12-11   AON         1      -0.062755 -0.008135 -0.000146
# 18216   2019-12-11   AIG         1      -0.095644 -0.007978 -0.006895
# ...            ...   ...       ...            ...       ...       ...
# 19120   2019-12-11  ULTA        -1      -0.274497 -0.021168  0.005073
# 18750   2019-12-11  IDXX        -1      -0.141388 -0.021133 -0.009453
# 18820   2019-12-11    LW        -1      -0.153222 -0.021107  0.004285
# 18238   2019-12-11  BALL        -1      -0.357772 -0.021053 -0.000626
# 18232   2019-12-11  ADSK        -1      -0.264341 -0.020923  0.006612
#
# [388 rows x 6 columns]
#
#
# Date: 2020-01-29
# Total return equals position * return, daily: -0.0038742796289456165
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 19859   2020-01-29   DVA         1      -0.072041 -0.006075  0.002171
# 19591   2020-01-29   WBA         1      -0.199491 -0.006022 -0.009473
# 20129   2020-01-29   LYB         1      -0.316967 -0.006006  0.011094
# 19965   2020-01-29   CRL         1      -0.083358 -0.005985  0.004970
# 19769   2020-01-29    CB         1      -0.183121 -0.005952 -0.000464
# ...            ...   ...       ...            ...       ...       ...
# 19205   2020-01-29   AVY        -1      -0.236873 -0.018449  0.054330
# 19807   2020-01-29   MAA        -1      -0.196123 -0.018382 -0.006257
# 19339   2020-01-29   GIS        -1      -0.168973 -0.018355  0.000377
# 19789   2020-01-29    LW        -1      -0.153222 -0.018211  0.004255
# 19369   2020-01-29  HUBB        -1      -0.229505 -0.017975  0.004571
#
# [388 rows x 6 columns]
#
#
# Date: 2020-03-03
# Total return equals position * return, daily: -0.019254585631754813
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 19860   2020-03-03   DVA         1      -0.072041 -0.006075 -0.056792
# 19592   2020-03-03   WBA         1      -0.199491 -0.006022 -0.041364
# 20130   2020-03-03   LYB         1      -0.316967 -0.006006 -0.030596
# 19966   2020-03-03   CRL         1      -0.083358 -0.005985 -0.016981
# 19770   2020-03-03    CB         1      -0.183121 -0.005952 -0.037086
# ...            ...   ...       ...            ...       ...       ...
# 19206   2020-03-03   AVY        -1      -0.236873 -0.018449 -0.012309
# 19808   2020-03-03   MAA        -1      -0.196123 -0.018382  0.013811
# 19340   2020-03-03   GIS        -1      -0.168973 -0.018355  0.004668
# 19790   2020-03-03    LW        -1      -0.153222 -0.018211 -0.013272
# 19370   2020-03-03  HUBB        -1      -0.229505 -0.017975 -0.047541
#
# [388 rows x 6 columns]
#
#
# Date: 2020-04-29
# Total return equals position * return, daily: 0.04586019692960747
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 20857   2020-04-29  AMZN         1      -0.092063 -0.005429  0.025336
# 20825   2020-04-29    EG         1      -0.066906 -0.005373  0.026718
# 20965   2020-04-29   CNC         1      -0.121771 -0.005299 -0.014888
# 20137   2020-04-29   ABT         1      -0.071820 -0.005263  0.008966
# 21085   2020-04-29  TRGP         1      -0.095981 -0.005103  0.156102
# ...            ...   ...       ...            ...       ...       ...
# 20457   2020-04-29  PCAR        -1      -0.382389 -0.018444  0.006217
# 20153   2020-04-29   AFL        -1      -0.124568 -0.018210  0.037047
# 20939   2020-04-29   MCO        -1      -0.051115 -0.018131  0.011705
# 20173   2020-04-29   ADP        -1      -0.148401 -0.018089  0.019789
# 20245   2020-04-29    DE        -1      -0.250561 -0.018007  0.039136
#
# [388 rows x 6 columns]
#
#
# Date: 2020-06-10
# Total return equals position * return, daily: -0.04194220704190894
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 20858   2020-06-10  AMZN         1      -0.092063 -0.005429  0.017913
# 20826   2020-06-10    EG         1      -0.066906 -0.005373 -0.025367
# 20966   2020-06-10   CNC         1      -0.121771 -0.005299 -0.019187
# 20138   2020-06-10   ABT         1      -0.071820 -0.005263  0.020937
# 21086   2020-06-10  TRGP         1      -0.095981 -0.005103 -0.054065
# ...            ...   ...       ...            ...       ...       ...
# 20458   2020-06-10  PCAR        -1      -0.382389 -0.018444 -0.027233
# 20154   2020-06-10   AFL        -1      -0.124568 -0.018210 -0.027612
# 20940   2020-06-10   MCO        -1      -0.051115 -0.018131  0.006618
# 20174   2020-06-10   ADP        -1      -0.148401 -0.018089 -0.010464
# 20246   2020-06-10    DE        -1      -0.250561 -0.018007 -0.023117
#
# [388 rows x 6 columns]
#
#
# Date: 2020-07-29
# Total return equals position * return, daily: 0.01616428576787403
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 21703   2020-07-29   HUM         1      -0.108034 -0.007437  0.025217
# 21195   2020-07-29     C         1      -0.047349 -0.007403  0.024381
# 21415   2020-07-29   NUE         1      -0.185371 -0.007276  0.013827
# 21191   2020-07-29   AON         1      -0.062755 -0.007236  0.000292
# 21727   2020-07-29   BWA         1      -0.162929 -0.007137  0.010909
# ...            ...   ...       ...            ...       ...       ...
# 21181   2020-07-29   CHD        -1      -0.124303 -0.021655  0.012470
# 21239   2020-07-29   ECL        -1      -0.261715 -0.021346  0.005730
# 21387   2020-07-29   MMM        -1      -0.124528 -0.021326  0.005923
# 21939   2020-07-29  NFLX        -1      -0.172921 -0.021226 -0.008250
# 21835   2020-07-29   BXP        -1      -0.157699 -0.021191 -0.005926
#
# [388 rows x 6 columns]
#
#
# Date: 2020-09-16
# Total return equals position * return, daily: 0.022656023421879924
#
#
#       meeting_date tiker  position  negative tone    tone_p    return
# 21704   2020-09-16   HUM         1      -0.108034 -0.007437 -0.002300
# 21196   2020-09-16     C         1      -0.047349 -0.007403  0.027003
# 21416   2020-09-16   NUE         1      -0.185371 -0.007276  0.016457
# 21192   2020-09-16   AON         1      -0.062755 -0.007236  0.002624
# 21728   2020-09-16   BWA         1      -0.162929 -0.007137 -0.064112
# ...            ...   ...       ...            ...       ...       ...
# 21182   2020-09-16   CHD        -1      -0.124303 -0.021655 -0.004007
# 21240   2020-09-16   ECL        -1      -0.261715 -0.021346  0.005759
# 21388   2020-09-16   MMM        -1      -0.124528 -0.021326  0.017650
# 21940   2020-09-16  NFLX        -1      -0.172921 -0.021226 -0.024456
# 21836   2020-09-16   BXP        -1      -0.157699 -0.021191  0.024610
#
# [388 rows x 6 columns]

# %%
# Convert the list of results to a DataFrame
results_df = pd.DataFrame(results_list)
results_df.to_csv('port_results.csv', index=False)

# %%
results_df.sum()
# Out:
# Date            2011-04-272011-06-222011-11-022012-01-252012-0...
# Total Return                                             0.009698
# dtype: object
